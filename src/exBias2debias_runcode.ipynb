# %% [markdown]
# # Exploting Bias to Debias
# - Original
#     - [GitHub](https://github.com/textshuttle/exploiting-bias-to-debias)
#     - [Paper](https://aclanthology.org/2023.acl-long.246.pdf)

# %% [markdown]
# ### workflow
# 1. `git clone https://github.com/textshuttle/exploiting-bias-to-debias.git`
# 2. `bash utils/create_venv.sh`
# 3. Generating More Data Using LM
#     - OSCAR 2021: load dataset from Huggingface (O)
#     - OSCAR 2023: sent access request mail (O)

# %%
# example with OSCAR 2201
from datasets import load_dataset


dataset = load_dataset("oscar-corpus/OSCAR-2201",
                        use_auth_token='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', # required
                        language="ko", 
                        streaming=True, # optional
                        split="train") # optional

n = 0
for d in dataset:   # prints documents 
    print(d)
    n += 1
    if n >= 20:
        break
# Out:
# /home/yumin/.conda/envs/test_env3/lib/python3.11/site-packages/datasets/load.py:2089: FutureWarning: 'use_auth_token' was deprecated in favor of 'token' in version 2.14.0 and will be removed in 3.0.0.
# You can remove this warning by passing 'token=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' instead.
#   warnings.warn(
# ...

# %%
dataset
